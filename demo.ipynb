# %% [markdown]
# <a href="https://colab.research.google.com/github/FangYang970206/MaskRCNN-Keypoint-Demo/blob/master/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/FangYang970206/MaskRCNN-Keypoint-Demo
# Out:
# Cloning into 'MaskRCNN-Keypoint-Demo'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 33 (delta 10), reused 27 (delta 4), pack-reused 0
# Unpacking objects: 100% (33/33), done.

# %%
cd MaskRCNN-Keypoint-Demo
# Out:
# /content/MaskRCNN-Keypoint-Demo/MaskRCNN-Keypoint-Demo/MaskRCNN-Keypoint-Demo

# %%
# !wget https://www.dropbox.com/s/5ctrg3br94srrx9/mask_rcnn_coco.h5
# Out:
# --2018-12-09 03:56:14--  https://www.dropbox.com/s/5ctrg3br94srrx9/mask_rcnn_coco.h5
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.82.1, 2620:100:6032:1::a27d:5201
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.82.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/5ctrg3br94srrx9/mask_rcnn_coco.h5 [following]
# --2018-12-09 03:56:15--  https://www.dropbox.com/s/raw/5ctrg3br94srrx9/mask_rcnn_coco.h5
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc1cc8af2830420eb41eff97aac9.dl.dropboxusercontent.com/cd/0/inline/AXFqR6HBJO71LhexGsr-HhJk9Q9kXJ50C0qy4M40LyBYz0-sAkVd9s3lDrEodMOLBw6a6Rx6ijzEk6Ye7RWnjN-vLzok6lCQBO4B6PlII0LGGxeBafjOVlq6JyilcoKLmPcvi9Z50ZPlP9-HQaF_SRA58cPBshR9m_5EhT_7-8-r5V60qLHUxueK_J6bAOTcVoA/file [following]
# ...

# %%
# !ls
# Out:
# coco.py     config.py  main.py		  media     README.md
# colors.txt  gif        mask_rcnn_coco.h5  model.py  utils.py

# %%
# !pip install -q pillow
# !pip install -q h5py
# !pip install opencv-python
# !pip install -U scikit-image
# !pip install -U cython
# !pip install "git+https://github.com/philferriere/cocoapi.git#egg=pycocotools&subdirectory=PythonAPI"
# !pip install keras==2.1.6 --force-reinstall
# Out:
# ...
# Requirement already up-to-date: scikit-image in /usr/local/lib/python3.6/dist-packages (0.14.1)
# ...
# Requirement already up-to-date: cython in /usr/local/lib/python3.6/dist-packages (0.29.1)
# ...
#   Using cached https://files.pythonhosted.org/packages/54/e8/eaff7a09349ae9bd40d3ebaf028b49f5e2392c771f294910f75bb608b241/Keras-2.1.6-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/ff/7f/9d804d2348471c67a7d8b5f84f9bc59fd1cefa148986f2b74552f8573555/numpy-1.15.4-cp36-cp36m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/8e/cb/726134109e7bd71d98d1fcc717ffe051767aac42ede0e7326fd1787e5d64/h5py-2.8.0-cp36-cp36m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/a8/0b/f163da98d3a01b3e0ef1cab8dd2123c34aee2bafbb1c5bffa354cc8a1730/scipy-1.1.0-cp36-cp36m-manylinux1_x86_64.whl
# ...

# %%
import cv2 as cv 
import numpy as np
def load(name):
    """
    Given an url of an image, downloads the image and
    returns a PIL image
    """
    image = cv.imread(name)
    # convert to BGR format
    image = np.array(image)
    return image
  
def imshow(img):
    plt.imshow(img[:, :, [2, 1, 0]])
    plt.axis("off")

# %%
image = load("media/ski.jpg")
imshow(image)

# %%
# !python main.py --image media/ski.jpg
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/sparse_ops.py:1165: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# 2018-12-09 03:57:15.011748: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-12-09 03:57:15.012255: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2018-12-09 03:57:15.012298: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# ...

# %%
image_out = load("media/ski_mask_rcnn_out_py.jpg")
imshow(image_out)
